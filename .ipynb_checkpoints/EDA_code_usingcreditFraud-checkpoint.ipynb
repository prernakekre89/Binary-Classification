# %% [markdown]
# Import packages:

# %%
#General
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

#Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# User Defined Functions:

# %% [markdown]
# Import Data:

# %%
data = pd.read_excel("C:\\Users\\91881\\Desktop\\CreditData\\default of credit card clients.xls", header = 1)

# %%
#view Column names:
#data.columns
data.dtypes

#check for missing values in the columns: 
#data.isnull().any()
#data.isna().any()
#data.dropna() # to drop null values from dataset

#data.head()
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
cat_col = ['ID','SEX','EDUCATION','MARRIAGE','default payment next month']
data[cat_col] = data[cat_col].apply(lambda x: x.astype('category'))

# %%
data.loc[:,data.columns != 'ID'].describe()
# Out:
#             LIMIT_BAL           AGE         PAY_0         PAY_2         PAY_3  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667     35.485500     -0.016700     -0.133767     -0.166200
# std     129747.661567      9.217904      1.123802      1.197186      1.196868
# min      10000.000000     21.000000     -2.000000     -2.000000     -2.000000
# 25%      50000.000000     28.000000     -1.000000     -1.000000     -1.000000
# 50%     140000.000000     34.000000      0.000000      0.000000      0.000000
# 75%     240000.000000     41.000000      0.000000      0.000000      0.000000
# max    1000000.000000     79.000000      8.000000      8.000000      8.000000
#
#               PAY_4         PAY_5         PAY_6      BILL_AMT1      BILL_AMT2  \
# count  30000.000000  30000.000000  30000.000000   30000.000000   30000.000000
# mean      -0.220667     -0.266200     -0.291100   51223.330900   49179.075167
# ...

# %%
data.drop(columns = 'ID').hist(figsize=(20,20))
plt.show()

# %%
(np.(data.PAY_AMT1)).hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ac645a029038> in <module>
# ----> 1 (np.exp(data.PAY_AMT1)).hist()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#     110         bins=bins,
#     111         legend=legend,
# --> 112         **kwargs,
#     113     )
#     114
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     352         if legend:
#     353             kwds["label"] = self.name
# --> 354         ax.hist(values, bins=bins, **kwds)
#     355         if legend:
#     356             ax.legend()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
data.PAY_0.unique()
# Out:
# array([ 2, -1,  0, -2,  1,  3,  4,  8,  7,  5,  6], dtype=int64)

# %%
pd.crosstab(data.PAY_0, data["default payment next month"], normalize='index').plot.bar()

# %%
pd.crosstab(data.EDUCATION, data["default payment next month"], normalize='index').plot.bar()

# %%
data.plot.scatter(x='BILL_AMT1',
                y='LIMIT_BAL',
                c='default payment next month',
                colormap='viridis'
                 )

# %%
sns.catplot(x="EDUCATION", y="LIMIT_BAL", hue="default payment next month", kind="box", data=data)

# %%
corr = data.corr()
corr

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data.drop(columns =['ID']).corr(),annot=True);

# %%
pd.crosstab(data.SEX, data['default payment next month'], normalize = True)*100

# %%
sns.catplot(x="SEX", y="default payment next month", hue="EDUCATION", kind="point", data=data)

# %%
'''sns.catplot(x="EDUCATION", y="PAY_0", hue="default payment next month",
            col="SEX", aspect=.7,kind="swarm", data=data)'''
